# %% [markdown]
# # 🌍 Lahore AQI Forecasting — Run Pipeline on Colab
# Use this notebook to run the heavy processing (sequence building, IDW interpolation, and model training) on Google Colab using a GPU.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

import os
# UPDATE THIS PATH if your project folder has a different name in your Drive
PROJECT_ROOT = '/content/drive/MyDrive/Air-Quality-Forecasting'
os.chdir(PROJECT_ROOT)
print(f'Current working directory: {os.getcwd()}')

# %%
# Install required dependencies
# !pip install -q -r requirements-dev.txt xgboost pyarrow openaq

# %%
# Run the full pipeline (skipping ingestion since you already have data)
# This will build the IDW sequences, train models, and save them back to your Drive.
# !python main.py --skip-ingestion
